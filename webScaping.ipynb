# %% [markdown]
# <a href="https://colab.research.google.com/github/NYARANGA-ROB/Hashing_UsingJava/blob/main/webScaping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
standings_url= "https://fbref.com/en/comps/9/Premier-league-Stats"
data = requests.get(standings_url)

from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]

links = standings_table.find_all('a')
links =[l.get('href') for l in links]
links = [l for l in links if '/squads' in l]
team_urls= [f"https://fbref.com{l}" for l in links]
team_urls
# Out:
# ['https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/19538871/Manchester-United-Stats',
#  'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  'https://fbref.com/en/squads/8602292d/Aston-Villa-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/cd051869/Brentford-Stats',
#  'https://fbref.com/en/squads/fd962109/Fulham-Stats',
#  'https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  'https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats',
#  'https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats',
#  'https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  'https://fbref.com/en/squads/d3fd31cc/Everton-Stats',
#  'https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats',
#  'https://fbref.com/en/squads/5bfb9659/Leeds-United-Stats',
#  'https://fbref.com/en/squads/33c895d4/Southampton-Stats']

# %%
team_url= team_urls[0]
data = requests.get(team_url)
import pandas as pd
matches = pd.read_html(data.text, match= "Scores & Fixtures")
matches [0]
# Out:
#           Date   Time              Comp                Round  Day    Venue  \
# 0   2022-07-30  17:00  Community Shield  FA Community Shield  Sat  Neutral
# 1   2022-08-07  16:30    Premier League          Matchweek 1  Sun     Away
# 2   2022-08-13  15:00    Premier League          Matchweek 2  Sat     Home
# 3   2022-08-21  16:30    Premier League          Matchweek 3  Sun     Away
# 4   2022-08-27  15:00    Premier League          Matchweek 4  Sat     Home
# ..         ...    ...               ...                  ...  ...      ...
# 56  2023-05-21  16:00    Premier League         Matchweek 37  Sun     Home
# 57  2023-05-24  20:00    Premier League         Matchweek 32  Wed     Away
# 58  2023-05-28  16:30    Premier League         Matchweek 38  Sun     Away
# 59  2023-06-03  15:00            FA Cup                Final  Sat  Neutral
# 60  2023-06-10  22:00      Champions Lg                Final  Sat  Neutral
#
#    Result  GF  GA        Opponent   xG  xGA  Poss  Attendance  \
# 0       L   1   3       Liverpool  NaN  NaN    57         NaN
# 1       W   2   0        West Ham  2.2  0.5    75     62443.0
# 2       W   4   0     Bournemouth  1.7  0.1    67     53453.0
# 3       D   3   3   Newcastle Utd  2.1  1.8    69     52258.0
# 4       W   4   2  Crystal Palace  2.2  0.1    74     53112.0
# ..    ...  ..  ..             ...  ...  ...   ...         ...
# 56      W   1   0         Chelsea  1.2  1.2    64     53490.0
# 57      D   1   1        Brighton  1.8  2.2    60     31388.0
# 58      L   0   1       Brentford  1.6  1.3    65     17120.0
# 59      W   2   1  Manchester Utd  NaN  NaN    60     83179.0
# 60      W   1   0        it Inter  1.0  1.7    55     71412.0
#
#             Captain Formation           Referee  Match Report Notes
# 0        Rúben Dias     4-3-3      Craig Pawson  Match Report   NaN
# 1    İlkay Gündoğan     4-3-3    Michael Oliver  Match Report   NaN
# 2    İlkay Gündoğan   4-2-3-1       David Coote  Match Report   NaN
# 3    İlkay Gündoğan     4-3-3    Jarred Gillett  Match Report   NaN
# 4   Kevin De Bruyne   4-2-3-1    Darren England  Match Report   NaN
# ..              ...       ...               ...           ...   ...
# 56      Kyle Walker    3-4-3◆    Michael Oliver  Match Report   NaN
# 57   İlkay Gündoğan     4-3-3      Simon Hooper  Match Report   NaN
# 58      Kyle Walker   3-2-4-1       John Brooks  Match Report   NaN
# 59   İlkay Gündoğan   3-2-4-1      Paul Tierney  Match Report   NaN
# 60   İlkay Gündoğan   3-2-4-1  Szymon Marciniak  Match Report   NaN
#
# [61 rows x 19 columns]

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links= [l.get ("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
links
# Out:
# ['/en/squads/b8fd03ef/2022-2023/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2022-2023/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2022-2023/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2022-2023/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")
shooting = pd.read_html(data.text, match= "Shooting")[0]
shooting
# Out:
#    For Manchester City                                                     \
#                   Date   Time              Comp                Round  Day
# 0           2022-07-30  17:00  Community Shield  FA Community Shield  Sat
# 1           2022-08-07  16:30    Premier League          Matchweek 1  Sun
# 2           2022-08-13  15:00    Premier League          Matchweek 2  Sat
# 3           2022-08-21  16:30    Premier League          Matchweek 3  Sun
# 4           2022-08-27  15:00    Premier League          Matchweek 4  Sat
# ..                 ...    ...               ...                  ...  ...
# 57          2023-05-24  20:00    Premier League         Matchweek 32  Wed
# 58          2023-05-28  16:30    Premier League         Matchweek 38  Sun
# 59          2023-06-03  15:00            FA Cup                Final  Sat
# 60          2023-06-10  22:00      Champions Lg                Final  Sat
# 61                 NaN    NaN               NaN                  NaN  NaN
#
#                                                ... Standard                  \
#       Venue   Result   GF  GA        Opponent  ...     Dist    FK  PK PKatt
# 0   Neutral        L    1   3       Liverpool  ...      NaN   NaN   0     0
# 1      Away        W    2   0        West Ham  ...     18.7   1.0   1     1
# 2      Home        W    4   0     Bournemouth  ...     17.5   0.0   0     0
# 3      Away        D    3   3   Newcastle Utd  ...     16.2   1.0   0     0
# 4      Home        W    4   2  Crystal Palace  ...     14.1   0.0   0     0
# ..      ...      ...  ...  ..             ...  ...      ...   ...  ..   ...
# 57     Away        D    1   1        Brighton  ...     13.9   0.0   0     0
# 58     Away        L    0   1       Brentford  ...     16.8   0.0   0     0
# 59  Neutral        W    2   1  Manchester Utd  ...      NaN   NaN   0     0
# 60  Neutral        W    1   0        it Inter  ...     16.9   0.0   0     0
# 61      NaN  44-10-7  151  46             NaN  ...     16.8  24.0  14    18
#
#    Expected                             Unnamed: 25_level_0
#          xG  npxG npxG/Sh  G-xG np:G-xG        Match Report
# 0       NaN   NaN     NaN   NaN     NaN        Match Report
# 1       2.2   1.4    0.11  -0.2    -0.4        Match Report
# 2       1.7   1.7    0.09   1.3     1.3        Match Report
# 3       2.1   2.1    0.10   0.9     0.9        Match Report
# 4       2.2   2.2    0.13   1.8     1.8        Match Report
# ..      ...   ...     ...   ...     ...                 ...
# 57      1.8   1.8    0.14  -0.8    -0.8        Match Report
# 58      1.6   1.6    0.11  -1.6    -1.6        Match Report
# 59      NaN   NaN     NaN   NaN     NaN        Match Report
# 60      1.0   1.0    0.14   0.0     0.0        Match Report
# 61    105.2  93.8    0.12  42.8    40.2                 NaN
#
# [62 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()
shooting.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2022-07-30  17:00  Community Shield  FA Community Shield  Sat  Neutral
# 1  2022-08-07  16:30    Premier League          Matchweek 1  Sun     Away
# 2  2022-08-13  15:00    Premier League          Matchweek 2  Sat     Home
# 3  2022-08-21  16:30    Premier League          Matchweek 3  Sun     Away
# 4  2022-08-27  15:00    Premier League          Matchweek 4  Sat     Home
#
#   Result  GF  GA        Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  \
# 0      L   1   3       Liverpool  ...   NaN  NaN   0      0  NaN   NaN
# 1      W   2   0        West Ham  ...  18.7  1.0   1      1  2.2   1.4
# 2      W   4   0     Bournemouth  ...  17.5  0.0   0      0  1.7   1.7
# 3      D   3   3   Newcastle Utd  ...  16.2  1.0   0      0  2.1   2.1
# 4      W   4   2  Crystal Palace  ...  14.1  0.0   0      0  2.2   2.2
#
#    npxG/Sh  G-xG  np:G-xG  Match Report
# 0      NaN   NaN      NaN  Match Report
# 1     0.11  -0.2     -0.4  Match Report
# 2     0.09   1.3      1.3  Match Report
# 3     0.10   0.9      0.9  Match Report
# 4     0.13   1.8      1.8  Match Report
#
# [5 rows x 26 columns]

# %%
team_data = matches[0].merge(shooting[["Date","Sh","SoT","Dist","FK","PK","PKatt"]], on= "Date")
shooting.shape
# Out:
# (62, 26)

# %%
team_data.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2022-07-30  17:00  Community Shield  FA Community Shield  Sat  Neutral
# 1  2022-08-07  16:30    Premier League          Matchweek 1  Sun     Away
# 2  2022-08-13  15:00    Premier League          Matchweek 2  Sat     Home
# 3  2022-08-21  16:30    Premier League          Matchweek 3  Sun     Away
# 4  2022-08-27  15:00    Premier League          Matchweek 4  Sat     Home
#
#   Result  GF  GA        Opponent  ...  Formation         Referee  \
# 0      L   1   3       Liverpool  ...      4-3-3    Craig Pawson
# 1      W   2   0        West Ham  ...      4-3-3  Michael Oliver
# 2      W   4   0     Bournemouth  ...    4-2-3-1     David Coote
# 3      D   3   3   Newcastle Utd  ...      4-3-3  Jarred Gillett
# 4      W   4   2  Crystal Palace  ...    4-2-3-1  Darren England
#
#    Match Report  Notes  Sh SoT  Dist   FK PK  PKatt
# 0  Match Report    NaN  14   8   NaN  NaN  0      0
# 1  Match Report    NaN  13   1  18.7  1.0  1      1
# 2  Match Report    NaN  19   7  17.5  0.0  0      0
# 3  Match Report    NaN  21  10  16.2  1.0  0      0
# 4  Match Report    NaN  18   5  14.1  0.0  0      0
#
# [5 rows x 25 columns]

# %%
years = list(range(2022,2010, -1))

# %%
years
# Out:
# [2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011]

# %%
all_matches = []

# %%
standings_url= "https://fbref.com/en/comps/9/Premier-league-Stats"

# %%
import time

for year in years:
  data = requests.get(standings_url)
  soup = BeautifulSoup(data.text)
  try:
    standings_table = soup.select('table.stats_table')[0]
  except IndexError:
    continue
  links = [l.get("href")for l in standings_table.find_all('a')]
  links = [ l for  l in links if '/squads/' in l]
  team_urls = [f"https://fbref.com{l}" for l in links]
  for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")

    data =requests.get(team_url)
    try:
      matches = pd.read_html(data.text, match="Scores & Fixtures")[0]






      soup = BeautifulSoup(data.text)
      links = [l.get("href") for l in soup.find_all('a')]
      links = [l for l in links if l and 'all_comps/shooting/' in l]
      data = requests.get(f"https://fbref.com{links[0]}")
      shooting = pd.read_html(data.text, match="Shooting")[0]
      shooting.columns = shooting.columns.droplevel()

      team_data = matches.merge(shooting[["Date","Sh","SoT","Dist","FK","PK","PKatt"]], on= "Date")
    except ValueError:
      continue
    team_data = team_data[team_data["Comp"]=="Premier League"]
    team_data["Season"] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)
    time.sleep(1)
# Out:
# <ipython-input-12-26753d50249c>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data["Season"] = year
# <ipython-input-12-26753d50249c>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data["Team"] = team_name

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df.to_csv("matches.csv")

# %%
matches
# Out:
#           Date   Time            Comp                Round  Day Venue Result  \
# 0   2022-08-06  15:00  Premier League          Matchweek 1  Sat  Home      W
# 1   2022-08-13  15:00  Premier League          Matchweek 2  Sat  Away      D
# 2   2022-08-21  14:00  Premier League          Matchweek 3  Sun  Home      W
# 3   2022-08-24  19:45         EFL Cup         Second round  Wed  Home      W
# 4   2022-08-27  15:00  Premier League          Matchweek 4  Sat  Away      L
# 5   2022-08-30  20:00  Premier League          Matchweek 5  Tue  Home      D
# 6   2022-09-03  15:00  Premier League          Matchweek 6  Sat  Away      L
# 7   2022-10-02  16:30  Premier League          Matchweek 9  Sun  Home      D
# 8   2022-10-09  14:00  Premier League         Matchweek 10  Sun  Away      L
# 9   2022-10-16  14:00  Premier League         Matchweek 11  Sun  Home      L
# 10  2022-10-20  20:15  Premier League         Matchweek 12  Thu  Away      L
# 11  2022-10-23  14:00  Premier League         Matchweek 13  Sun  Home      L
# 12  2022-10-29  19:45  Premier League         Matchweek 14  Sat  Away      W
# 13  2022-11-05  15:00  Premier League         Matchweek 15  Sat  Home      W
# 14  2022-11-09  19:45         EFL Cup          Third round  Wed  Away      L
# 15  2022-11-12  15:00  Premier League         Matchweek 16  Sat  Away      L
# 16  2022-12-28  20:00  Premier League         Matchweek 17  Wed  Home      L
# 17  2022-12-31  15:00  Premier League         Matchweek 18  Sat  Away      D
# 18  2023-01-04  19:45  Premier League         Matchweek 19  Wed  Home      D
# 19  2023-01-08  14:00          FA Cup   Third round proper  Sun  Away      D
# 20  2023-01-13  20:00  Premier League         Matchweek 20  Fri  Away      L
# 21  2023-01-18  19:45          FA Cup   Third round proper  Wed  Home      W
# 22  2023-01-22  14:00  Premier League         Matchweek 21  Sun  Home      D
# 23  2023-01-28  12:30          FA Cup  Fourth round proper  Sat  Away      W
# 24  2023-02-05  14:00  Premier League         Matchweek 22  Sun  Away      L
# 25  2023-02-08  20:00  Premier League          Matchweek 8  Wed  Away      D
# 26  2023-02-12  14:00  Premier League         Matchweek 23  Sun  Home      L
# 27  2023-02-18  15:00  Premier League         Matchweek 24  Sat  Away      L
# 28  2023-02-25  15:00  Premier League         Matchweek 25  Sat  Home      W
# 29  2023-02-28  19:45          FA Cup   Fifth round proper  Tue  Away      L
# 30  2023-03-04  15:00  Premier League         Matchweek 26  Sat  Away      L
# 31  2023-03-11  15:00  Premier League         Matchweek 27  Sat  Home      D
# 32  2023-03-18  15:00  Premier League         Matchweek 28  Sat  Away      W
# 33  2023-04-01  15:00  Premier League         Matchweek 29  Sat  Away      L
# 34  2023-04-04  19:45  Premier League          Matchweek 7  Tue  Home      W
# 35  2023-04-09  14:00  Premier League         Matchweek 30  Sun  Home      L
# 36  2023-04-17  20:00  Premier League         Matchweek 31  Mon  Home      L
# 37  2023-04-22  12:30  Premier League         Matchweek 32  Sat  Away      L
# 38  2023-04-25  20:00  Premier League         Matchweek 33  Tue  Home      D
# 39  2023-04-30  14:00  Premier League         Matchweek 34  Sun  Away      L
# 40  2023-05-06  15:00  Premier League         Matchweek 35  Sat  Away      L
# 41  2023-05-13  12:30  Premier League         Matchweek 36  Sat  Home      D
# 42  2023-05-21  13:30  Premier League         Matchweek 37  Sun  Away      L
# 43  2023-05-28  16:30  Premier League         Matchweek 38  Sun  Home      L
#
#     GF  GA         Opponent   xG  xGA  Poss  Attendance          Captain  \
# 0    2   1           Wolves  0.8  1.3    40       36347  Patrick Bamford
# 1    2   2      Southampton  1.8  1.2    57       30815  Patrick Bamford
# 2    3   0          Chelsea  2.1  0.9    39       36372          Rodrigo
# 3    3   1         Barnsley  NaN  NaN    71       35472      Liam Cooper
# 4    0   1         Brighton  1.8  2.0    56       30953          Rodrigo
# 5    1   1          Everton  1.0  1.0    69       36338          Rodrigo
# 6    2   5        Brentford  1.7  2.3    68       17092       Robin Koch
# 7    0   0      Aston Villa  0.4  2.2    44       36582      Liam Cooper
# 8    1   2   Crystal Palace  1.0  1.1    46       25042      Liam Cooper
# 9    0   1          Arsenal  1.8  0.5    47       36700      Liam Cooper
# 10   0   2   Leicester City  1.3  0.8    54       30814  Patrick Bamford
# 11   2   3           Fulham  1.6  1.8    57       36447      Liam Cooper
# 12   2   1        Liverpool  1.8  1.7    32       53274      Liam Cooper
# 13   4   3      Bournemouth  2.2  1.5    60       36304      Liam Cooper
# 14   0   1           Wolves  NaN  NaN    52       24246      Luke Ayling
# 15   3   4        Tottenham  1.1  1.8    45       61667      Liam Cooper
# 16   1   3  Manchester City  0.6  4.3    31       36889      Liam Cooper
# 17   0   0    Newcastle Utd  0.4  2.2    40       52211      Liam Cooper
# 18   2   2         West Ham  1.6  1.4    62       36173      Liam Cooper
# 19   2   2     Cardiff City  NaN  NaN    73       20324   Pascal Struijk
# 20   1   2      Aston Villa  2.4  1.2    48       42008      Liam Cooper
# 21   5   2     Cardiff City  NaN  NaN    52       34465          Rodrigo
# 22   0   0        Brentford  0.5  0.4    58       36260      Luke Ayling
# 23   3   1  Acc'ton Stanley  NaN  NaN    59        5268  Patrick Bamford
# 24   0   1  Nott'ham Forest  0.9  0.4    70       29363      Liam Cooper
# 25   2   2   Manchester Utd  0.6  2.0    34       73456      Luke Ayling
# 26   0   2   Manchester Utd  1.8  1.1    34       36919      Luke Ayling
# 27   0   1          Everton  0.5  1.4    49       39232      Luke Ayling
# 28   1   0      Southampton  0.9  0.4    61       36641      Luke Ayling
# 29   0   2           Fulham  NaN  NaN    46       19359      Luke Ayling
# 30   0   1          Chelsea  1.0  1.5    43       39905      Luke Ayling
# 31   2   2         Brighton  0.9  2.7    38       36471      Luke Ayling
# 32   4   2           Wolves  1.6  2.7    35       31570      Luke Ayling
# 33   1   4          Arsenal  0.7  3.8    34       60283      Luke Ayling
# 34   2   1  Nott'ham Forest  1.8  0.8    61       36740      Luke Ayling
# 35   1   5   Crystal Palace  0.9  3.0    48       36427      Luke Ayling
# 36   1   6        Liverpool  1.4  2.7    27       36657          Rodrigo
# 37   1   2           Fulham  0.8  1.7    50       24356      Liam Cooper
# 38   1   1   Leicester City  1.5  2.1    41       36666      Liam Cooper
# 39   1   4      Bournemouth  1.6  1.9    58       10434      Liam Cooper
# 40   1   2  Manchester City  0.2  2.6    20       53406      Luke Ayling
# 41   2   2    Newcastle Utd  2.1  2.4    36       36955      Luke Ayling
# 42   1   3         West Ham  0.9  2.1    41       62478      Luke Ayling
# 43   1   4        Tottenham  1.5  2.2    52       36871      Liam Cooper
#
#    Formation            Referee  Match Report  Notes
# 0    4-2-3-1       Robert Jones  Match Report    NaN
# 1    4-2-3-1    Tony Harrington  Match Report    NaN
# 2    4-2-3-1     Stuart Attwell  Match Report    NaN
# 3      4-3-3        John Brooks  Match Report    NaN
# 4    4-2-3-1  Michael Salisbury  Match Report    NaN
# 5    4-2-3-1     Darren England  Match Report    NaN
# 6    4-2-3-1       Robert Jones  Match Report    NaN
# 7    4-2-3-1     Stuart Attwell  Match Report    NaN
# 8    4-2-3-1       Paul Tierney  Match Report    NaN
# 9    4-2-3-1     Chris Kavanagh  Match Report    NaN
# 10   4-2-3-1       Peter Bankes  Match Report    NaN
# 11   4-2-3-1     Anthony Taylor  Match Report    NaN
# 12   4-2-3-1     Michael Oliver  Match Report    NaN
# 13   4-2-3-1    Tony Harrington  Match Report    NaN
# 14   4-2-3-1     Andre Marriner  Match Report    NaN
# 15   4-2-3-1  Michael Salisbury  Match Report    NaN
# 16     4-3-3     Stuart Attwell  Match Report    NaN
# 17   4-2-3-1       Simon Hooper  Match Report    NaN
# 18   4-2-3-1        David Coote  Match Report    NaN
# 19     4-4-2     Jarred Gillett  Match Report    NaN
# 20   4-2-3-1     Michael Oliver  Match Report    NaN
# 21   4-2-3-1     Thomas Bramall  Match Report    NaN
# 22   4-2-3-1       Peter Bankes  Match Report    NaN
# 23   4-1-3-2       Joshua Smith  Match Report    NaN
# 24   4-2-3-1       Robert Jones  Match Report    NaN
# 25   4-2-3-1       Simon Hooper  Match Report    NaN
# 26   4-2-3-1       Paul Tierney  Match Report    NaN
# 27   4-2-3-1        Andy Madley  Match Report    NaN
# 28   4-2-3-1       Peter Bankes  Match Report    NaN
# 29     4-3-3     Chris Kavanagh  Match Report    NaN
# 30   4-2-3-1     Michael Oliver  Match Report    NaN
# 31   4-2-3-1       Paul Tierney  Match Report    NaN
# 32   4-2-3-1  Michael Salisbury  Match Report    NaN
# 33     4-3-3     Darren England  Match Report    NaN
# 34   4-2-3-1       Robert Jones  Match Report    NaN
# 35   4-2-3-1       Simon Hooper  Match Report    NaN
# 36   4-2-3-1       Craig Pawson  Match Report    NaN
# 37   4-2-3-1       Peter Bankes  Match Report    NaN
# 38   4-2-3-1       Paul Tierney  Match Report    NaN
# 39     3-4-3     Chris Kavanagh  Match Report    NaN
# 40   4-2-3-1        Andy Madley  Match Report    NaN
# 41     4-3-3       Simon Hooper  Match Report    NaN
# 42     4-3-3       Peter Bankes  Match Report    NaN
# 43     5-4-1     Anthony Taylor  Match Report    NaN
